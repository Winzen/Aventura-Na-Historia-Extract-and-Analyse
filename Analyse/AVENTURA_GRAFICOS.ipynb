# %%
import pandas as pd
import sqlite3
import matplotlib.pyplot as plt
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
 ("Materias", 'Noticias', 'Curiosidade', 'CoronaVirus')
# Out:
# ('Materias', 'Noticias', 'Curiosidade', 'CoronaVirus')

# %%
base = sqlite3.connect("/content/drive/MyDrive/DataBase/AventuraPoste.db")
df = pd.read_sql("SELECT * FROM Poste", base, parse_dates=['Data'], index_col='Data')

Categoria = "Geral"
Ano = 2021

df['year'] = df.index.year
df['month'] = df.index.month
df = df[(df.index.year == Ano)]
df = df[df['Categoria'] == Categoria] if Categoria != 'Geral' else df
df['year'] = df.index.year
df['month'] = df.index.month
df = (df.groupby(['Nome','month']))['Categoria'].count().unstack()
df = df.drop("Redação")
df = df.fillna(0)
df.columns = ['Janeiro', 'Fevereiro', 'Março', 'Abril', 'Maio', 'Junho', 'Julho', 'Agosto', 'Setembro', 'Outubro', 'Novembro', 'Dezembro']

top10 = df.sum(axis=1).sort_values(ascending=False)[:10]


fig, ax = plt.subplots(dpi=100, figsize=(20, 12))
for nome in top10.index:
  df[df.index == nome].iloc[0].plot(marker='o', legend=True, ax=ax)


#####
fig2, ax2 = plt.subplots(dpi=100,figsize=(15, 5))
top10.plot(kind="barh", ax=ax2)
for index, y in enumerate(top10):
  ax2.text(y, index + 0.15 , str(y), fontweight='bold')

ax2.grid(b = True, color ='grey',
        linestyle ='-.', linewidth = 0.5,
        alpha = 0.2)

ax2.invert_yaxis()
ax2.set_title(f"TOTAL DE PUBLICAÇOES DOS PRINCIPAIS AUTORES.{5*' '}CATEGORIA: {Categoria.upper()} ANO: {Ano}")
ax2.set_xlabel("Total De Publicações")
ax2.set_ylabel("Nomes")
fig2.text(0.130, 0.902, Categoria, style='italic',
        fontsize=15, 
        horizontalalignment='left',
        bbox={'facecolor': 'black', 'alpha': 0.5, 'pad': 5})

#ESTILO
plt.style.use("dark_background")

for param in ['text.color', 'axes.labelcolor', 'xtick.color', 'ytick.color']:
  plt.rcParams[param] = '0.9'  # very light grey

for param in ['figure.facecolor', 'axes.facecolor', 'savefig.facecolor']:
  plt.rcParams[param] = '#212946'  # bluish dark grey

ax.grid(color='#2A3459')

fig.text(0.128, 0.89, Categoria, style='italic',
        fontsize=15, 
        horizontalalignment='left',
        bbox={'facecolor': 'black', 'alpha': 0.5, 'pad': 5})
ax.set_xlim([ax.get_xlim()[0] - 0.2, ax.get_xlim()[1] + 0.2])  # to not have the markers cut off
ax.set_ylim(0)
ax.set_xlabel("Mêses")
ax.set_ylabel("Postes")
ax.set_xticks([x for x in range(0, 13)])
ax.set_xticklabels(df.columns)
ax.legend(title='Autores')

ax.set_title(f"PRINCIPAIS AUTORES E SUA FRENQUECIA POR MÊS.{5*' '}CATEGORIA: {Categoria.upper()} ANO: {Ano}")
#ESTILO

# %%
base = sqlite3.connect("/content/drive/MyDrive/DataBase/AventuraPoste.db")
df = pd.read_sql("SELECT * FROM Poste", base, parse_dates=['Data'], index_col='Data')
catego =  ("Materias", 'Noticias', 'Curiosidade', 'CoronaVirus')
Categoria = "Geral"
Ano = 2020
dicionario_df_categorias = {}


df['year'] = df.index.year
df['month'] = df.index.month
df = df[(df.index.year == Ano)]

for categorias in df['Categoria'].unique():
  
  dicionario_df_categorias[categorias] = df[df['Categoria'] == categorias]
  dicionario_df_categorias[categorias] = (dicionario_df_categorias[categorias].groupby(['Nome','month']))['Categoria'].count().unstack()
  dicionario_df_categorias[categorias].columns = ['Janeiro', 'Fevereiro', 'Março', 'Abril', 'Maio', 'Junho', 'Julho', 'Agosto', 'Setembro', 'Outubro', 'Novembro', 'Dezembro']
  dicionario_df_categorias[categorias] = dicionario_df_categorias[categorias].fillna(0)


for categoria, dfs in dicionario_df_categorias.items():
  
  multiplicador = 1
  if categoria == 'Materias':
    multiplicador = 2
  elif categoria == 'Curiosidade':
    multiplicador = 1.5
  
  dicionario_df_categorias[categoria] = dicionario_df_categorias[categoria] * multiplicador

df = list(dicionario_df_categorias.values())[0]
soma = list(dicionario_df_categorias.values())[1:]

for dfs in soma: 
  df = df.add(dfs, fill_value=0)

df = df.drop("Redação")

top10 = df.sum(axis=1).sort_values(ascending=False)[:10]

fig, ax = plt.subplots(dpi=100, figsize=(20, 12))

for nome in top10.index:
  df[df.index == nome].iloc[0].plot(marker='o', legend=True, ax=ax)


#####
fig2, ax2 = plt.subplots(dpi=100,figsize=(15, 5))
top10.plot(kind="barh", ax=ax2)
for index, y in enumerate(top10):
  ax2.text(y, index + 0.15 , str(y), fontweight='bold')

ax2.grid(b = True, color ='grey',
        linestyle ='-.', linewidth = 0.5,
        alpha = 0.2)

ax2.invert_yaxis()
ax2.set_title(f"TOTAL DE PUBLICAÇOES DOS PRINCIPAIS AUTORES.{5*' '}CATEGORIA: {Categoria.upper()} ANO: {Ano}")
ax2.set_xlabel("Total De Publicações")
ax2.set_ylabel("Nomes")
fig2.text(0.130, 0.902, Categoria, style='italic',
        fontsize=15, 
        horizontalalignment='left',
        bbox={'facecolor': 'black', 'alpha': 0.5, 'pad': 5})

#ESTILO
plt.style.use("dark_background")

for param in ['text.color', 'axes.labelcolor', 'xtick.color', 'ytick.color']:
  plt.rcParams[param] = '0.9'  # very light grey

for param in ['figure.facecolor', 'axes.facecolor', 'savefig.facecolor']:
  plt.rcParams[param] = '#212946'  # bluish dark grey

ax.grid(color='#2A3459')

fig.text(0.128, 0.89, Categoria, style='italic',
        fontsize=15, 
        horizontalalignment='left',
        bbox={'facecolor': 'black', 'alpha': 0.5, 'pad': 5})
ax.set_xlim([ax.get_xlim()[0] - 0.2, ax.get_xlim()[1] + 0.2])  # to not have the markers cut off
ax.set_ylim(0)
ax.set_xlabel("Mêses")
ax.set_ylabel("Postes")
ax.set_xticks([x for x in range(0, 13)])
ax.set_xticklabels(df.columns)
ax.legend(title='Autores')

ax.set_title(f"PRINCIPAIS AUTORES E SUA FRENQUECIA POR MÊS.{5*' '}CATEGORIA: {Categoria.upper()} ANO: {Ano}")
#ESTILO
# Out:
# Text(0.5, 1.0, 'PRINCIPAIS AUTORES E SUA FRENQUECIA POR MÊS.     CATEGORIA: GERAL ANO: 2020')

# %%
base = sqlite3.connect("/content/drive/MyDrive/DataBase/AventuraPoste.db")
df = pd.read_sql("SELECT * FROM Poste", base, parse_dates=['Data'], index_col='Data')

Categoria = "Geral"
Ano = 2021

df['year'] = df.index.year
df['month'] = df.index.month
df = df[(df.index.year == Ano)]

top10  = df['Nome'].value_counts()


top10 = top10[:]/df['Nome'].count()
df2 = pd.Series([top10[11:].sum()], index=['Outros'])
top10 = top10[0:11]
top10 = top10.append(df2)
top10 = top10*100


fig2, ax2 = plt.subplots(dpi=100,figsize=(15, 5))
top10.plot(kind="barh", ax=ax2)
for index, y in enumerate(top10):
  ax2.text(y, index + 0.15 , f'{y:.2f}%', fontweight='bold')

ax2.grid(b = True, color ='grey',
        linestyle ='-.', linewidth = 0.5,
        alpha = 0.2)

ax2.invert_yaxis()
ax2.set_title(f"TOTAL DE PUBLICAÇOES DOS PRINCIPAIS AUTORES.{5*' '}CATEGORIA: {Categoria.upper()} ANO: {Ano}")
ax2.set_xlabel("Total De Publicações")
ax2.set_ylabel("Nomes")
fig2.text(0.130, 0.902, Categoria, style='italic',
        fontsize=15, 
        horizontalalignment='left',
        bbox={'facecolor': 'black', 'alpha': 0.5, 'pad': 5})

#ESTILO
plt.style.use("dark_background")

for param in ['text.color', 'axes.labelcolor', 'xtick.color', 'ytick.color']:
  plt.rcParams[param] = '0.9'  # very light grey

for param in ['figure.facecolor', 'axes.facecolor', 'savefig.facecolor']:
  plt.rcParams[param] = '#212946'  # bluish dark grey

# %%
base = sqlite3.connect("/content/drive/MyDrive/DataBase/AventuraPoste.db")
df = pd.read_sql("SELECT * FROM Poste", base, parse_dates=['Data'], index_col='Data')

nome_autor = "Ingredi Brunato"

df = df[df['Nome'] == nome_autor] 
df['year'] = df.index.year
df['month'] = df.index.month

df = (df.groupby(['year','month']))['Categoria'].count().unstack()

df = df.fillna(0)
df.columns = ['Janeiro', 'Fevereiro', 'Março', 'Abril', 'Maio', 'Junho', 'Julho', 'Agosto', 'Setembro', 'Outubro', 'Novembro', 'Dezembro']

top10 = df.sum(axis=1).sort_values(ascending=False)[:10]

fig, ax = plt.subplots(dpi=100, figsize=(20, 12))

for nome in top10.index:
  df[df.index == nome].iloc[0].plot(marker='o', legend=True, ax=ax)


#####
fig2, ax2 = plt.subplots(dpi=100,figsize=(15, 5))
top10.plot(kind="barh", ax=ax2)
for index, y in enumerate(top10):
  ax2.text(y, index + 0.15 , str(y), fontweight='bold')

ax2.grid(b = True, color ='grey',
        linestyle ='-.', linewidth = 0.5,
        alpha = 0.2)

ax2.invert_yaxis()
ax2.set_title(f"TOTAL DE PUBLICAÇOES DOS PRINCIPAIS AUTORES.")
ax2.set_xlabel("Total De Publicações")
ax2.set_ylabel("Nomes")
fig2.text(0.130, 0.902, nome_autor, style='italic',
        fontsize=15, 
        horizontalalignment='left',
        bbox={'facecolor': 'black', 'alpha': 0.5, 'pad': 5})

#ESTILO
plt.style.use("dark_background")


for param in ['text.color', 'axes.labelcolor', 'xtick.color', 'ytick.color']:
  plt.rcParams[param] = '0.9'  # very light grey

for param in ['figure.facecolor', 'axes.facecolor', 'savefig.facecolor']:
  plt.rcParams[param] = '#212946'  # bluish dark grey

ax.grid(color='#2A3459')

fig.text(0.128, 0.89, nome_autor, style='italic',
        fontsize=15, 
        horizontalalignment='left',
        bbox={'facecolor': 'black', 'alpha': 0.5, 'pad': 5})
ax.set_xlim([ax.get_xlim()[0] - 0.2, ax.get_xlim()[1] + 0.2])  # to not have the markers cut off
ax.set_ylim(0)
ax.set_xlabel("Mêses")
ax.set_ylabel("Postes")
ax.set_xticks([x for x in range(0, 13)])
ax.set_xticklabels(df.columns)
ax.legend(title='Autores')

ax.set_title(f"PRINCIPAIS AUTORES E SUA FRENQUECIA POR MÊS.")
#ESTILO
# Out:
#       Janeiro  Fevereiro  Março  Abril  Maio  Junho  Julho  Agosto  Setembro  \
# year
# 2020       17         10     14     12    31     12     15      60        83
# 2021       90         67     86     78    77     33     93      98       110
#
#       Outubro  Novembro  Dezembro
# year
# 2020       81        72        60
# 2021       90        75        81
# Text(0.5, 1.0, 'PRINCIPAIS AUTORES E SUA FRENQUECIA POR MÊS.')

# %%
1. Numero de publicaçoes
2. Pontuação
3. Porcetagem de Publicaçoes
4. Publicaçoes Individuais

# %%
def estilo(df, top10):

  fig, ax = plt.subplots(dpi=100, figsize=(20, 12))

  for nome in top10.index:
    df[df.index == nome].iloc[0].plot(marker='o', legend=True, ax=ax)


  #####
  fig2, ax2 = plt.subplots(dpi=100,figsize=(15, 5))
  top10.plot(kind="barh", ax=ax2)
  for index, y in enumerate(top10):
    ax2.text(y, index + 0.15 , str(y), fontweight='bold')

  ax2.grid(b = True, color ='grey',
          linestyle ='-.', linewidth = 0.5,
          alpha = 0.2)

  ax2.invert_yaxis()
  ax2.set_title(f"TOTAL DE PUBLICAÇOES DOS PRINCIPAIS AUTORES.{5*' '}CATEGORIA: {Categoria.upper()} ANO: {Ano}")
  ax2.set_xlabel("Total De Publicações")
  ax2.set_ylabel("Nomes")
  fig2.text(0.130, 0.902, Categoria, style='italic',
          fontsize=15, 
          horizontalalignment='left',
          bbox={'facecolor': 'black', 'alpha': 0.5, 'pad': 5})

  #ESTILO
  plt.style.use("dark_background")

  for param in ['text.color', 'axes.labelcolor', 'xtick.color', 'ytick.color']:
    plt.rcParams[param] = '0.9'  # very light grey

  for param in ['figure.facecolor', 'axes.facecolor', 'savefig.facecolor']:
    plt.rcParams[param] = '#212946'  # bluish dark grey

  ax.grid(color='#2A3459')

  fig.text(0.128, 0.89, Categoria, style='italic',
          fontsize=15, 
          horizontalalignment='left',
          bbox={'facecolor': 'black', 'alpha': 0.5, 'pad': 5})
  ax.set_xlim([ax.get_xlim()[0] - 0.2, ax.get_xlim()[1] + 0.2])  # to not have the markers cut off
  ax.set_ylim(0)
  ax.set_xlabel("Mêses")
  ax.set_ylabel("Postes")
  ax.set_xticks([x for x in range(0, 13)])
  ax.set_xticklabels(df.columns)
  ax.legend(title='Autores')

  ax.set_title(f"PRINCIPAIS AUTORES E SUA FRENQUECIA POR MÊS.{5*' '}CATEGORIA: {Categoria.upper()} ANO: {Ano}")
  #ESTILO

# %%
def painel_geral(df, numero_publicaçoes=False, pontuação=False, 
                  porcetagem_publicaçoes=False, individual=False, Ano=2020, Categoria="Geral", nome_autor="Ingredi Brunato"):
  Categoria = "Geral"
  Ano = 2020
  if numero_publicaçoes:
    Categoria = "Geral"
    Ano = 2020

    df['year'] = df.index.year
    df['month'] = df.index.month
    df = df[(df.index.year == Ano)]
    df = df[df['Categoria'] == Categoria] if Categoria != 'Geral' else df
    df['year'] = df.index.year
    df['month'] = df.index.month
    df = (df.groupby(['Nome','month']))['Categoria'].count().unstack()
    df = df.drop("Redação")
    df = df.fillna(0)
    df.columns = ['Janeiro', 'Fevereiro', 'Março', 'Abril', 'Maio', 'Junho', 'Julho', 'Agosto', 'Setembro', 'Outubro', 'Novembro', 'Dezembro']

    top10 = df.sum(axis=1).sort_values(ascending=False)[:10]

 
  elif pontuação:
    catego =  ("Materias", 'Noticias', 'Curiosidade', 'CoronaVirus')
    dicionario_df_categorias = {}


    df['year'] = df.index.year
    df['month'] = df.index.month
    df = df[(df.index.year == Ano)]

    for categorias in df['Categoria'].unique():
      
      dicionario_df_categorias[categorias] = df[df['Categoria'] == categorias]
      dicionario_df_categorias[categorias] = (dicionario_df_categorias[categorias].groupby(['Nome','month']))['Categoria'].count().unstack()
      dicionario_df_categorias[categorias].columns = ['Janeiro', 'Fevereiro', 'Março', 'Abril', 'Maio', 'Junho', 'Julho', 'Agosto', 'Setembro', 'Outubro', 'Novembro', 'Dezembro']
      dicionario_df_categorias[categorias] = dicionario_df_categorias[categorias].fillna(0)


    for categoria, dfs in dicionario_df_categorias.items():
      
      multiplicador = 1
      if categoria == 'Materias':
        multiplicador = 2
      elif categoria == 'Curiosidade':
        multiplicador = 1.5
      
      dicionario_df_categorias[categoria] = dicionario_df_categorias[categoria] * multiplicador

    df = list(dicionario_df_categorias.values())[0]
    soma = list(dicionario_df_categorias.values())[1:]

    for dfs in soma: 
      df = df.add(dfs, fill_value=0)

    df = df.drop("Redação")

    top10 = df.sum(axis=1).sort_values(ascending=False)[:10]
  
  elif porcetagem_publicaçoes:
    return  
  elif individual:

    df = df[df['Nome'] == nome_autor] 
    df['year'] = df.index.year
    df['month'] = df.index.month

    df = (df.groupby(['year','month']))['Categoria'].count().unstack()

    df = df.fillna(0)
    df.columns = ['Janeiro', 'Fevereiro', 'Março', 'Abril', 'Maio', 'Junho', 'Julho', 'Agosto', 'Setembro', 'Outubro', 'Novembro', 'Dezembro']

    top10 = df.sum(axis=1).sort_values(ascending=False)[:10]

  estilo(df, top10)

# %%
base = sqlite3.connect("/content/drive/MyDrive/DataBase/AventuraPoste.db")
df = pd.read_sql("SELECT * FROM Poste", base, parse_dates=['Data'], index_col='Data')
painel_geral(df, individual=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:66: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
